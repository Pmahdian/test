# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import sklearn.metrics as sm

# %%
df_train = pd.read_csv('q1.csv')
df_test = pd.read_csv('q2.csv')

# %%
df_test.head()
# Out:
#     x1  x2       y
# 0  803  35  646872
# 1  444  13  197762
# 2    9  92    8646
# 3  970  19  942250
# 4  458   1  210224

# %%
x_train = df_train.drop('y', axis=1)
y_train = df_train['y']

# %%
y_train
# Out:
# 0      108600
# 1      113906
# 2      717554
# 3      427334
# 4      214248
#         ...
# 995    497490
# 996    157746
# 997     28292
# 998    505272
# 999    246644
# Name: y, Length: 1000, dtype: int64

# %%
x_test = df_test.drop('y', axis=1)
y_test = df_test['y']

# %%
x_test
# Out:
#      x1  x2
# 0   803  35
# 1   444  13
# 2     9  92
# 3   970  19
# 4   458   1
# ..  ...  ..
# 95  352  12
# 96  315  68
# 97  672  60
# 98   41  62
# 99  867  23
#
# [100 rows x 2 columns]

# %%
model = linear_model.LogisticRegression(max_iter=10000)

# %%
model.fit(x_train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=10000)

# %%
y_pr = model.predict(x_test)
y_pr
# Out:
# array([759330, 216140,   7250, 928674, 261634, 231342, 120874, 994882,
#        630126, 285212, 946364, 401526, 319404,  41870,  25022,   7442,
#        450798, 980322, 450942,  29052,  15126, 216140,    690,  29036,
#        261634, 216140,  33738,   6458, 364862,  48084, 851706,  81930,
#         65812, 586920,    894, 595376, 231342, 231342, 706802,    606,
#        988596, 163584, 618714, 464202, 706802,  26140, 466676, 618714,
#          1730,  15126,  65812, 485256,  29052,  65812, 972692, 981110,
#        320030, 823976, 470636, 201240, 243366, 862114, 540612,  55992,
#        337052,   6312, 539310,  19884, 231342,   4332, 842406, 740070,
#        386394, 127436,  76064, 113906,  80086,  57072, 234782, 433704,
#         57072, 171168,   8256, 389304, 341642,   7442, 163584,  57072,
#        231342, 231342, 286322, 134972, 216140, 400146, 450798, 120134,
#        102838, 425272,   7442, 842406])

# %%
y_test
# Out:
# 0     646872
# 1     197762
# 2       8646
# 3     942250
# 4     210224
#        ...
# 95    124412
# 96    104232
# 97    455916
# 98      5628
# 99    753108
# Name: y, Length: 100, dtype: int64
