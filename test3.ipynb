# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import sklearn.metrics as sm

# %%
df_train = pd.read_csv('q1.csv')
df_test = pd.read_csv('q2.csv')

# %%
df_test.head()
# Out:
#     x1  x2       y
# 0  803  35  646872
# 1  444  13  197762
# 2    9  92    8646
# 3  970  19  942250
# 4  458   1  210224

# %%
x_train = df_train.drop('y', axis=1)
y_train = df_train['y']

# %%
y_train
# Out:
# 0      108600
# 1      113906
# 2      717554
# 3      427334
# 4      214248
#         ...
# 995    497490
# 996    157746
# 997     28292
# 998    505272
# 999    246644
# Name: y, Length: 1000, dtype: int64

# %%
x_test = df_test.drop('y', axis=1)
y_test = df_test['y']

# %%
x_test
# Out:
#      x1  x2
# 0   803  35
# 1   444  13
# 2     9  92
# 3   970  19
# 4   458   1
# ..  ...  ..
# 95  352  12
# 96  315  68
# 97  672  60
# 98   41  62
# 99  867  23
#
# [100 rows x 2 columns]

# %%
model = linear_model.LogisticRegression(max_iter=10000)

# %%
model.fit(x_train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=10000)

# %%
y_pr = model.predict(x_test)
y_pr
# Out:
# array([ 639089.58812661,  278621.85037668, -147844.16764446,
#         804211.84609815,  291424.11939364,  236222.6145811 ,
#         184267.59999094,  734136.33612547,  583878.80412813,
#         344244.75600021,  746774.7599251 ,  440790.42602321,
#         386360.46308437,   36405.97208169,  -18001.90999552,
#         -95703.22697533,  470853.32510247,  742999.61730694,
#         495525.99853511,  -31163.22949473,  -67365.81523268,
#         351559.1967381 , -148514.58439595,   11617.13764472,
#         309390.04874475,  406357.48934513,    4888.31270156,
#         -77648.97417771,  468825.75068256,   17863.7061218 ,
#         697747.82430856,  142759.58956314,    9643.00413401,
#         591690.53721423, -138728.71779914,  573223.79302516,
#         215089.2392682 ,  263854.72703494,  601051.11074391,
#        -159959.6957445 ,  812108.38014101,  199985.14630584,
#         573963.97485129,  515226.69440876,  609035.96823329,
#         -13445.94631773,  513838.17669277,  584845.55126673,
#        -151238.17891874,  -71846.25713964,   61349.37255007,
#         492789.60233664,  -31456.0373921 ,  -52825.25720342,
#         759860.55765348,  772410.65800659,  429628.84338609,
#         700506.30136866,  507566.00486432,  277220.530985  ,
#         317491.06723846,  708828.12847866,  564294.26925881,
#          97268.42957659,  506612.0594014 ,  -91666.63650738,
#         530597.99191711,   -9267.59149408,  297324.43906417,
#        -155341.01197157,  698802.89489368,  652030.09900953,
#         450296.28639835,  204717.75687666,  113650.63594679,
#         154679.91239826,  145372.77977778,   49847.29780258,
#         348999.44743266,  466523.92673716,   60826.47685048,
#         252343.37310152,  -79915.91558579,  451369.91535535,
#         493236.9762654 , -124213.76312125,  177463.25327695,
#          26695.6272557 ,  309887.34109296,  215892.14118947,
#         382638.76137541,  219103.74887452,  311559.38752037,
#         423955.08902805,  489914.9642722 ,  186698.38661636,
#         155234.16814542,  510777.61254937, -118832.81666057,
#         701797.2164522 ])

# %%
y_test
# Out:
# 0     646872
# 1     197762
# 2       8646
# 3     942250
# 4     210224
#        ...
# 95    124412
# 96    104232
# 97    455916
# 98      5628
# 99    753108
# Name: y, Length: 100, dtype: int64
